# %%
# Definición de la funcion que recupera la información meteorológica de las estaciones de observación 
# existentes entre dos periodos de tiempo datos de la BBDD de Temperaturas Mundiales

# El resultado aparecerá agrupado por continente

import sqlite3
import pandas as pd
from pandas import DataFrame, Series
import time

def ejecucion_continentes(bbdd_file,continents,init_year,ending_year,outputfile_data,outputfile_stations):
    # Abrimos la conexión con la BBDD
    conn = sqlite3.connect(bbdd_file)
    cursor = conn.cursor()

    # Vamos a intentar automatizar el análisis anterior, es decir, considerar los datos a partir de cierto año y a 
    # continuacion filtrar por aquellas estaciones que tienen observaciones por año inferior a 364 dias
    df_total = DataFrame()
    df_estaciones = DataFrame()

    for cont in continents:
        print("Inicio continente: " + cont + " a las " + str(time.strftime("%H:%M:%S")))
        
        # Se recuperan todas las estaciones del continentes que existían previamente a 1900 y existen en 2016
        rows = cursor.execute("""select distinct station 
                                 from world_time_"""+cont+"""
                                 where date = '"""+str(init_year)+"0101';")

        station_list_init = []
        for r in rows:
            station_list_init.append(r[0])
            
        print ("   Numero estaciones en el año inicial: " + str(len(station_list_init)))

        if len(station_list_init) > 0:
            rows = cursor.execute("""select distinct station 
                                     from world_time_"""+cont+"""
                                     where date = '"""+str(ending_year)+"1231';")        
            station_list_ending = []
            for r in rows:
                station_list_ending.append({"station":r[0]})
                
            print ("   Numero estaciones en el año final: " + str(len(station_list_ending)))
                        
            station_list_ending = DataFrame(station_list_ending)
            station_list_ending = DataFrame(station_list_ending[station_list_ending.station.map(lambda x: x in station_list_init)])
            station_list_ending = station_list_ending.reset_index()[["station"]]
            print ("   Numero estaciones comunes: " + str(len(station_list_ending)))

            # Se itera de 100 en 100 estaciones
            df = DataFrame()
            station_list_ending = station_list_ending.station
            while(len(station_list_ending) > 0):
                if len(station_list_ending) > 100:
                    new = station_list_ending[:100]
                    station_list_ending = station_list_ending[100:]
                else:
                    new = station_list_ending
                    station_list_ending = []
                
                stats = ""
                for s in new:
                    if stats != "":
                        stats = stats + ","
                    stats = stats + "'" + s + "'" 
                                
                # De todas las estaciones anteriores, se recupera el número de observaciones no nulas por año
                rows = cursor.execute("""select date, substr(date,1,4) as year, station, tmax, tmin, 1 as n_records
                                         from world_time_"""+cont+"""
                                         where station in (""" + stats + """) and 
                                         date >= '""" + str(init_year) + """0101';""")

                data = DataFrame()
                result = rows.fetchmany(400000)
                while len(result) > 0:
                    data = data.append(DataFrame(result))
                    result = rows.fetchmany(400000)                
                    
                print("   Numero de registros recuperados de las estaciones: " + str(len(data)))
                
                if len(data) > 0:
                    data.columns = ["date","year","station","tmax","tmin","n_records"]                
                    data = data.dropna()
                    data = data[data.tmin > -60.0]
                    data = data[data.tmax < 60.0]
                    data = data[data.year.map(lambda x: int(x) >= init_year)]
                    data = data[data.year.map(lambda x: int(x) <= ending_year)]
                    data_year = data[["year","station","n_records"]].groupby(["year","station"]).sum()
                    data_year = data_year.reset_index()
                                
                    # Nos quedamos con aquellas estaciones que tienen menos de 360 observaciones por año
                    less_360_obs = data_year[data_year.n_records < 360][["station"]].drop_duplicates().station
                                
                    # Eliminamos las estaciones con menos de 360 observaciones del dataframe de datos
                    if len(less_360_obs) > 0:
                        data = data[data.station.map(lambda x: x not in less_360_obs.as_matrix())]
                        data_year = data_year[data_year.station.map(lambda x: x not in less_360_obs.as_matrix())]
                    
                    print("   Numero de estaciones: " + str(len(data.station.drop_duplicates())))
                
                    less_360_obs = []
                    with_gaps = []
                    
                    # Se buscan las estaciones que tienen al menos un año sin información
                    for s in data_year[["station"]].drop_duplicates().station:
                        sub_data_year = data_year[data_year.station == s]
                        prev_year = init_year-1
                        ind_gap = 0
                        for y in sub_data_year[["year"]].year:
                            if int(y) - prev_year > 1 and ind_gap == 0:
                                ind_gap = ind_gap + 1
                                with_gaps.append(s)
                                
                            prev_year = int(y)

                        if ending_year - int(y) != 0 and ind_gap == 0:
                            with_gaps.append(s)
                        
                    # Se eliminan todas las estaciones con gaps
                    if len(with_gaps) > 0:
                        data = data[data.station.map(lambda x: x not in with_gaps)]
                
                    print("   Numero de estaciones: " + str(len(data.station.drop_duplicates())))
                
                    with_gaps = []
                    sub_data_year = DataFrame()
                    data_year = DataFrame()                
                    df = df.append(data)
                    sub_data = DataFrame()
                    
                    
                # En este momento se dispone de todos los datos esperados, se calculan los indicadores deseados
                estadisticas = {"tmax":{"max_tmax":"max","min_tmax":"min","tmax":"median","std_tmax":"std"},
                                "tmin":{"max_tmin":"max","min_tmin":"min","tmin":"median","std_tmin":"std"}}
                
                df.to_csv("../Datos/Resultados/Datos_estaciones_" + cont + "_" + str(init_year) +".csv")
                df_agg = df[["year","tmax","tmin"]].groupby("year").agg(estadisticas)
                df_agg.columns = df_agg.columns.droplevel()
                df_agg["continent"] = cont
                df_agg["period"] = str(init_year)+"-"+str(ending_year)
                df_total = df_total.append(df_agg)
                
                df_agg = df[["station"]].drop_duplicates()
                df_agg["continent"] = cont
                df_agg["period"] = str(init_year)+"-"+str(ending_year)
                df_estaciones = df_estaciones.append(df_agg)
                
    df_total.to_csv(outputfile_data)
    df_estaciones.to_csv(outputfile_stations)

    conn.close()

# %%
ejecucion_continentes("D:/master/Master-in-Data-Science/Proyecto/Datos/worldTimeSeries.sqlite",
                      ["europa","oceania","north_america","africa","asia","central_america","south_america","antarctica"],
                      1900,
                      2015,
                      "../Datos/Resultados/Resultado_calentamiento_1900_2015.csv",
                      "../Datos/Resultados/Resultado_calentamiento_1900_2015_estaciones.csv"                     
                     )
# Out:
# Inicio continente: europa a las 22:14:41
#    Numero estaciones en el año inicial: 142
#    Numero estaciones en el año final: 1416
#    Numero estaciones comunes: 90
#    Numero de registros recuperados de las estaciones: 2309606
#    Numero de estaciones: 11
#    Numero de estaciones: 4
# Inicio continente: oceania a las 22:20:57
#    Numero estaciones en el año inicial: 1742
#    Numero estaciones en el año final: 2248
#    Numero estaciones comunes: 1003
#    Numero de registros recuperados de las estaciones: 924639
#    Numero de estaciones: 1
#    Numero de estaciones: 1
#    Numero de registros recuperados de las estaciones: 1093200
#    Numero de estaciones: 1
#    Numero de estaciones: 0
#    Numero de registros recuperados de las estaciones: 911830
#    Numero de estaciones: 0
#    Numero de estaciones: 0
#    Numero de registros recuperados de las estaciones: 773223
#    Numero de estaciones: 1
#    Numero de estaciones: 1
#    Numero de registros recuperados de las estaciones: 618516
#    Numero de estaciones: 2
#    Numero de estaciones: 0
#    Numero de registros recuperados de las estaciones: 781107
#    Numero de estaciones: 1
#    Numero de estaciones: 0
#    Numero de registros recuperados de las estaciones: 635768
#    Numero de estaciones: 1
#    Numero de estaciones: 1
#    Numero de registros recuperados de las estaciones: 569856
#    Numero de estaciones: 0
#    Numero de estaciones: 0
#    Numero de registros recuperados de las estaciones: 710999
#    Numero de estaciones: 1
#    Numero de estaciones: 1
#    Numero de registros recuperados de las estaciones: 640252
#    Numero de estaciones: 0
#    Numero de estaciones: 0
#    Numero de registros recuperados de las estaciones: 10002
#    Numero de estaciones: 0
#    Numero de estaciones: 0
# Inicio continente: north_america a las 23:17:57
#    Numero estaciones en el año inicial: 1578
#    Numero estaciones en el año final: 6514
#    Numero estaciones comunes: 1290
#    Numero de registros recuperados de las estaciones: 3877487
#    Numero de estaciones: 8
#    Numero de estaciones: 8
#    Numero de registros recuperados de las estaciones: 4156367
#    Numero de estaciones: 15
#    Numero de estaciones: 15
#    Numero de registros recuperados de las estaciones: 4039684
#    Numero de estaciones: 13
#    Numero de estaciones: 13
#    Numero de registros recuperados de las estaciones: 4104084
#    Numero de estaciones: 30
#    Numero de estaciones: 30
#    Numero de registros recuperados de las estaciones: 4008887
#    Numero de estaciones: 14
#    Numero de estaciones: 14
#    Numero de registros recuperados de las estaciones: 3981773
#    Numero de estaciones: 23
#    Numero de estaciones: 23
#    Numero de registros recuperados de las estaciones: 3981553
#    Numero de estaciones: 20
#    Numero de estaciones: 20
#    Numero de registros recuperados de las estaciones: 4120616
#    Numero de estaciones: 16
#    Numero de estaciones: 16
#    Numero de registros recuperados de las estaciones: 4263984
#    Numero de estaciones: 18
#    Numero de estaciones: 18
#    Numero de registros recuperados de las estaciones: 3972964
#    Numero de estaciones: 12
#    Numero de estaciones: 12
#    Numero de registros recuperados de las estaciones: 3907465
#    Numero de estaciones: 8
#    Numero de estaciones: 8
#    Numero de registros recuperados de las estaciones: 4059057
#    Numero de estaciones: 17
#    Numero de estaciones: 17
#    Numero de registros recuperados de las estaciones: 3710761
#    Numero de estaciones: 17
#    Numero de estaciones: 16
# Inicio continente: africa a las 00:50:51
#    Numero estaciones en el año inicial: 163
#    Numero estaciones en el año final: 349
#    Numero estaciones comunes: 20
#    Numero de registros recuperados de las estaciones: 150916
#    Numero de estaciones: 0
#    Numero de estaciones: 0
# Inicio continente: asia a las 00:52:17
#    Numero estaciones en el año inicial: 94
#    Numero estaciones en el año final: 1631
#    Numero estaciones comunes: 74
#    Numero de registros recuperados de las estaciones: 2374712
#    Numero de estaciones: 0
#    Numero de estaciones: 0
# Inicio continente: central_america a las 00:58:10
#    Numero estaciones en el año inicial: 7
#    Numero estaciones en el año final: 81
#    Numero estaciones comunes: 2
#    Numero de registros recuperados de las estaciones: 59973
#    Numero de estaciones: 0
#    Numero de estaciones: 0
# Inicio continente: south_america a las 00:58:17
#    Numero estaciones en el año inicial: 0
# Inicio continente: antarctica a las 00:58:17
#    Numero estaciones en el año inicial: 0

# %%
ejecucion_continentes("D:/master/Master-in-Data-Science/Proyecto/Datos/worldTimeSeries.sqlite",
                      ["europa","oceania","north_america","africa","asia","central_america","south_america","antarctica"],
                      1950,
                      2015,
                      "../Datos/Resultados/Resultado_calentamiento_1950_2015.csv",
                      "../Datos/Resultados/Resultado_calentamiento_1950_2015_estaciones.csv"                     
                     )
# Out:
# Inicio continente: europa a las 00:58:18
#    Numero estaciones en el año inicial: 530
#    Numero estaciones en el año final: 1416
#    Numero estaciones comunes: 325
#    Numero de registros recuperados de las estaciones: 2081392
#    Numero de estaciones: 22
#    Numero de estaciones: 21
#    Numero de registros recuperados de las estaciones: 1278027
#    Numero de estaciones: 16
#    Numero de estaciones: 9
#    Numero de registros recuperados de las estaciones: 1937787
#    Numero de estaciones: 18
#    Numero de estaciones: 10
#    Numero de registros recuperados de las estaciones: 285064
#    Numero de estaciones: 0
#    Numero de estaciones: 0
# Inicio continente: oceania a las 01:15:40
#    Numero estaciones en el año inicial: 2572
#    Numero estaciones en el año final: 2248
#    Numero estaciones comunes: 1557
#    Numero de registros recuperados de las estaciones: 671829
#    Numero de estaciones: 2
#    Numero de estaciones: 1
#    Numero de registros recuperados de las estaciones: 861865
#    Numero de estaciones: 3
#    Numero de estaciones: 3
#    Numero de registros recuperados de las estaciones: 683932
#    Numero de estaciones: 3
#    Numero de estaciones: 3
#    Numero de registros recuperados de las estaciones: 698583
#    Numero de estaciones: 3
#    Numero de estaciones: 3
#    Numero de registros recuperados de las estaciones: 475223
#    Numero de estaciones: 1
#    Numero de estaciones: 1
#    Numero de registros recuperados de las estaciones: 377644
#    Numero de estaciones: 0
#    Numero de estaciones: 0
#    Numero de registros recuperados de las estaciones: 802016
#    Numero de estaciones: 3
#    Numero de estaciones: 3
#    Numero de registros recuperados de las estaciones: 410971
#    Numero de estaciones: 1
#    Numero de estaciones: 0
#    Numero de registros recuperados de las estaciones: 521667
#    Numero de estaciones: 1
#    Numero de estaciones: 0
#    Numero de registros recuperados de las estaciones: 586826
#    Numero de estaciones: 1
#    Numero de estaciones: 0
#    Numero de registros recuperados de las estaciones: 554209
#    Numero de estaciones: 1
#    Numero de estaciones: 1
#    Numero de registros recuperados de las estaciones: 443515
#    Numero de estaciones: 2
#    Numero de estaciones: 2
#    Numero de registros recuperados de las estaciones: 474848
#    Numero de estaciones: 0
#    Numero de estaciones: 0
#    Numero de registros recuperados de las estaciones: 591631
#    Numero de estaciones: 1
#    Numero de estaciones: 1
#    Numero de registros recuperados de las estaciones: 535384
#    Numero de estaciones: 0
#    Numero de estaciones: 0
#    Numero de registros recuperados de las estaciones: 488770
#    Numero de estaciones: 0
#    Numero de estaciones: 0
# Inicio continente: north_america a las 02:34:18
#    Numero estaciones en el año inicial: 3988
#    Numero estaciones en el año final: 6514
#    Numero estaciones comunes: 2753
#    Numero de registros recuperados de las estaciones: 2125474
#    Numero de estaciones: 18
#    Numero de estaciones: 18
#    Numero de registros recuperados de las estaciones: 2183142
#    Numero de estaciones: 8
#    Numero de estaciones: 8
#    Numero de registros recuperados de las estaciones: 2147592
#    Numero de estaciones: 21
#    Numero de estaciones: 21
#    Numero de registros recuperados de las estaciones: 1956903
#    Numero de estaciones: 26
#    Numero de estaciones: 26
#    Numero de registros recuperados de las estaciones: 1893573
#    Numero de estaciones: 19
#    Numero de estaciones: 19
#    Numero de registros recuperados de las estaciones: 2099756
#    Numero de estaciones: 32
#    Numero de estaciones: 32
#    Numero de registros recuperados de las estaciones: 2143708
#    Numero de estaciones: 33
#    Numero de estaciones: 33
#    Numero de registros recuperados de las estaciones: 2011553
#    Numero de estaciones: 29
#    Numero de estaciones: 29
#    Numero de registros recuperados de las estaciones: 2239378
#    Numero de estaciones: 49
#    Numero de estaciones: 49
#    Numero de registros recuperados de las estaciones: 2082794
#    Numero de estaciones: 23
#    Numero de estaciones: 22
#    Numero de registros recuperados de las estaciones: 2192296
#    Numero de estaciones: 40
#    Numero de estaciones: 39
#    Numero de registros recuperados de las estaciones: 2188315
#    Numero de estaciones: 35
#    Numero de estaciones: 35
#    Numero de registros recuperados de las estaciones: 2273342
#    Numero de estaciones: 45
#    Numero de estaciones: 45
#    Numero de registros recuperados de las estaciones: 2111716
#    Numero de estaciones: 24
#    Numero de estaciones: 24
#    Numero de registros recuperados de las estaciones: 2205485
#    Numero de estaciones: 33
#    Numero de estaciones: 33
#    Numero de registros recuperados de las estaciones: 2277301
#    Numero de estaciones: 38
#    Numero de estaciones: 38
#    Numero de registros recuperados de las estaciones: 2280368
#    Numero de estaciones: 32
#    Numero de estaciones: 32
#    Numero de registros recuperados de las estaciones: 2070060
#    Numero de estaciones: 24
#    Numero de estaciones: 24
#    Numero de registros recuperados de las estaciones: 2130496
#    Numero de estaciones: 29
#    Numero de estaciones: 29
#    Numero de registros recuperados de las estaciones: 2067514
#    Numero de estaciones: 20
#    Numero de estaciones: 20
#    Numero de registros recuperados de las estaciones: 2160513
#    Numero de estaciones: 31
#    Numero de estaciones: 31
#    Numero de registros recuperados de las estaciones: 2199460
#    Numero de estaciones: 38
#    Numero de estaciones: 38
#    Numero de registros recuperados de las estaciones: 2243618
#    Numero de estaciones: 39
#    Numero de estaciones: 39
#    Numero de registros recuperados de las estaciones: 2153274
#    Numero de estaciones: 40
#    Numero de estaciones: 40
#    Numero de registros recuperados de las estaciones: 2071198
#    Numero de estaciones: 46
#    Numero de estaciones: 45
#    Numero de registros recuperados de las estaciones: 2156364
#    Numero de estaciones: 56
#    Numero de estaciones: 56
#    Numero de registros recuperados de las estaciones: 2285576
#    Numero de estaciones: 54
#    Numero de estaciones: 54
#    Numero de registros recuperados de las estaciones: 1182484
#    Numero de estaciones: 27
#    Numero de estaciones: 27
# Inicio continente: africa a las 06:09:34
#    Numero estaciones en el año inicial: 754
#    Numero estaciones en el año final: 349
#    Numero estaciones comunes: 83
#    Numero de registros recuperados de las estaciones: 970193
#    Numero de estaciones: 0
#    Numero de estaciones: 0
# Inicio continente: asia a las 06:14:20
#    Numero estaciones en el año inicial: 2259
#    Numero estaciones en el año final: 1631
#    Numero estaciones comunes: 731
#    Numero de registros recuperados de las estaciones: 566607
#    Numero de estaciones: 0
#    Numero de estaciones: 0
#    Numero de registros recuperados de las estaciones: 1231574
#    Numero de estaciones: 0
#    Numero de estaciones: 0
#    Numero de registros recuperados de las estaciones: 1798617
#    Numero de estaciones: 0
#    Numero de estaciones: 0
#    Numero de registros recuperados de las estaciones: 1618600
#    Numero de estaciones: 0
#    Numero de estaciones: 0
#    Numero de registros recuperados de las estaciones: 1426460
#    Numero de estaciones: 0
#    Numero de estaciones: 0
#    Numero de registros recuperados de las estaciones: 1803846
#    Numero de estaciones: 0
#    Numero de estaciones: 0
#    Numero de registros recuperados de las estaciones: 1403253
#    Numero de estaciones: 0
#    Numero de estaciones: 0
#    Numero de registros recuperados de las estaciones: 453349
#    Numero de estaciones: 0
#    Numero de estaciones: 0
# Inicio continente: central_america a las 06:46:34
#    Numero estaciones en el año inicial: 36
#    Numero estaciones en el año final: 81
#    Numero estaciones comunes: 10
#    Numero de registros recuperados de las estaciones: 180039
#    Numero de estaciones: 0
#    Numero de estaciones: 0
# Inicio continente: south_america a las 06:46:59
#    Numero estaciones en el año inicial: 828
#    Numero estaciones en el año final: 255
#    Numero estaciones comunes: 18
#    Numero de registros recuperados de las estaciones: 100007
#    Numero de estaciones: 0
#    Numero de estaciones: 0
# Inicio continente: antarctica a las 06:48:08
#    Numero estaciones en el año inicial: 0

# %%
ejecucion_continentes("D:/master/Master-in-Data-Science/Proyecto/Datos/worldTimeSeries.sqlite",
                      ["europa","oceania","north_america","africa","asia","central_america","south_america","antarctica"],
                      1970,
                      2015,
                      "../Datos/Resultados/Resultado_calentamiento_1970_2015.csv",
                      "../Datos/Resultados/Resultado_calentamiento_1970_2015_estaciones.csv"                     
                     )
# Out:
# Inicio continente: europa a las 09:11:04
#    Numero estaciones en el año inicial: 1515
#    Numero estaciones en el año final: 1416
#    Numero estaciones comunes: 1055
#    Numero de registros recuperados de las estaciones: 1149877
#    Numero de estaciones: 26
#    Numero de estaciones: 22
#    Numero de registros recuperados de las estaciones: 1206078
#    Numero de estaciones: 22
#    Numero de estaciones: 19
#    Numero de registros recuperados de las estaciones: 1423204
#    Numero de estaciones: 32
#    Numero de estaciones: 32
#    Numero de registros recuperados de las estaciones: 383835
#    Numero de estaciones: 3
#    Numero de estaciones: 3
#    Numero de registros recuperados de las estaciones: 154235
#    Numero de estaciones: 8
#    Numero de estaciones: 8
#    Numero de registros recuperados de las estaciones: 0
#    Numero de registros recuperados de las estaciones: 969410
#    Numero de estaciones: 27
#    Numero de estaciones: 26
#    Numero de registros recuperados de las estaciones: 1581940
#    Numero de estaciones: 21
#    Numero de estaciones: 21
#    Numero de registros recuperados de las estaciones: 1341389
#    Numero de estaciones: 41
#    Numero de estaciones: 40
#    Numero de registros recuperados de las estaciones: 1122033
#    Numero de estaciones: 19
#    Numero de estaciones: 18
#    Numero de registros recuperados de las estaciones: 422059
#    Numero de estaciones: 0
#    Numero de estaciones: 0
# Inicio continente: oceania a las 10:00:02
#    Numero estaciones en el año inicial: 2884
#    Numero estaciones en el año final: 2248
#    Numero estaciones comunes: 1775
#    Numero de registros recuperados de las estaciones: 548997
#    Numero de estaciones: 2
#    Numero de estaciones: 2
#    Numero de registros recuperados de las estaciones: 696421
#    Numero de estaciones: 8
#    Numero de estaciones: 8
#    Numero de registros recuperados de las estaciones: 546496
#    Numero de estaciones: 3
#    Numero de estaciones: 3
#    Numero de registros recuperados de las estaciones: 416593
#    Numero de estaciones: 3
#    Numero de estaciones: 3
#    Numero de registros recuperados de las estaciones: 562889
#    Numero de estaciones: 7
#    Numero de estaciones: 7
#    Numero de registros recuperados de las estaciones: 325694
#    Numero de estaciones: 2
#    Numero de estaciones: 2
#    Numero de registros recuperados de las estaciones: 281907
#    Numero de estaciones: 0
#    Numero de estaciones: 0
#    Numero de registros recuperados de las estaciones: 602362
#    Numero de estaciones: 5
#    Numero de estaciones: 5
#    Numero de registros recuperados de las estaciones: 321115
#    Numero de estaciones: 0
#    Numero de estaciones: 0
#    Numero de registros recuperados de las estaciones: 335014
#    Numero de estaciones: 2
#    Numero de estaciones: 2
#    Numero de registros recuperados de las estaciones: 400747
#    Numero de estaciones: 1
#    Numero de estaciones: 1
#    Numero de registros recuperados de las estaciones: 592438
#    Numero de estaciones: 2
#    Numero de estaciones: 2
#    Numero de registros recuperados de las estaciones: 451980
#    Numero de estaciones: 1
#    Numero de estaciones: 1
#    Numero de registros recuperados de las estaciones: 259619
#    Numero de estaciones: 1
#    Numero de estaciones: 1
#    Numero de registros recuperados de las estaciones: 414809
#    Numero de estaciones: 1
#    Numero de estaciones: 1
#    Numero de registros recuperados de las estaciones: 405009
#    Numero de estaciones: 2
#    Numero de estaciones: 2
#    Numero de registros recuperados de las estaciones: 463969
#    Numero de estaciones: 1
#    Numero de estaciones: 1
#    Numero de registros recuperados de las estaciones: 587937
#    Numero de estaciones: 8
#    Numero de estaciones: 8
# Inicio continente: north_america a las 11:24:00
#    Numero estaciones en el año inicial: 4479
#    Numero estaciones en el año final: 6514
#    Numero estaciones comunes: 2927
#    Numero de registros recuperados de las estaciones: 1548544
#    Numero de estaciones: 20
#    Numero de estaciones: 20
#    Numero de registros recuperados de las estaciones: 1428540
#    Numero de estaciones: 4
#    Numero de estaciones: 4
#    Numero de registros recuperados de las estaciones: 1531974
#    Numero de estaciones: 8
#    Numero de estaciones: 8
#    Numero de registros recuperados de las estaciones: 1551310
#    Numero de estaciones: 18
#    Numero de estaciones: 18
#    Numero de registros recuperados de las estaciones: 1527781
#    Numero de estaciones: 32
#    Numero de estaciones: 32
#    Numero de registros recuperados de las estaciones: 1097287
#    Numero de estaciones: 8
#    Numero de estaciones: 8
#    Numero de registros recuperados de las estaciones: 1539854
#    Numero de estaciones: 40
#    Numero de estaciones: 40
#    Numero de registros recuperados de las estaciones: 1487981
#    Numero de estaciones: 25
#    Numero de estaciones: 25
#    Numero de registros recuperados de las estaciones: 1605489
#    Numero de estaciones: 49
#    Numero de estaciones: 49
#    Numero de registros recuperados de las estaciones: 1511479
#    Numero de estaciones: 46
#    Numero de estaciones: 46
#    Numero de registros recuperados de las estaciones: 1491173
#    Numero de estaciones: 36
#    Numero de estaciones: 36
#    Numero de registros recuperados de las estaciones: 1576975
#    Numero de estaciones: 36
#    Numero de estaciones: 34
#    Numero de registros recuperados de las estaciones: 1541907
#    Numero de estaciones: 52
#    Numero de estaciones: 51
#    Numero de registros recuperados de las estaciones: 1612595
#    Numero de estaciones: 47
#    Numero de estaciones: 47
#    Numero de registros recuperados de las estaciones: 1563187
#    Numero de estaciones: 50
#    Numero de estaciones: 50
#    Numero de registros recuperados de las estaciones: 1505017
#    Numero de estaciones: 29
#    Numero de estaciones: 29
#    Numero de registros recuperados de las estaciones: 1555420
#    Numero de estaciones: 40
#    Numero de estaciones: 40
#    Numero de registros recuperados de las estaciones: 1625289
#    Numero de estaciones: 41
#    Numero de estaciones: 41
#    Numero de registros recuperados de las estaciones: 1534528
#    Numero de estaciones: 37
#    Numero de estaciones: 37
#    Numero de registros recuperados de las estaciones: 1553506
#    Numero de estaciones: 48
#    Numero de estaciones: 48
#    Numero de registros recuperados de las estaciones: 1540760
#    Numero de estaciones: 30
#    Numero de estaciones: 30
#    Numero de registros recuperados de las estaciones: 1548611
#    Numero de estaciones: 34
#    Numero de estaciones: 34
#    Numero de registros recuperados de las estaciones: 1493111
#    Numero de estaciones: 39
#    Numero de estaciones: 39
#    Numero de registros recuperados de las estaciones: 1607597
#    Numero de estaciones: 50
#    Numero de estaciones: 50
#    Numero de registros recuperados de las estaciones: 1545881
#    Numero de estaciones: 39
#    Numero de estaciones: 39
#    Numero de registros recuperados de las estaciones: 1554256
#    Numero de estaciones: 46
#    Numero de estaciones: 46
#    Numero de registros recuperados de las estaciones: 1451221
#    Numero de estaciones: 53
#    Numero de estaciones: 52
#    Numero de registros recuperados de las estaciones: 1616470
#    Numero de estaciones: 65
#    Numero de estaciones: 65
#    Numero de registros recuperados de las estaciones: 1575984
#    Numero de estaciones: 53
#    Numero de estaciones: 53
#    Numero de registros recuperados de las estaciones: 453101
#    Numero de estaciones: 17
#    Numero de estaciones: 17
# Inicio continente: africa a las 15:55:30
#    Numero estaciones en el año inicial: 876
#    Numero estaciones en el año final: 349
#    Numero estaciones comunes: 121
#    Numero de registros recuperados de las estaciones: 824856
#    Numero de estaciones: 0
#    Numero de estaciones: 0
#    Numero de registros recuperados de las estaciones: 195766
#    Numero de estaciones: 0
#    Numero de estaciones: 0
# Inicio continente: asia a las 16:00:50
#    Numero estaciones en el año inicial: 3201
#    Numero estaciones en el año final: 1631
#    Numero estaciones comunes: 1314
#    Numero de registros recuperados de las estaciones: 1338173
#    Numero de estaciones: 0
#    Numero de estaciones: 0
#    Numero de registros recuperados de las estaciones: 1592500
#    Numero de estaciones: 3
#    Numero de estaciones: 0
#    Numero de registros recuperados de las estaciones: 734777
#    Numero de estaciones: 0
#    Numero de estaciones: 0
#    Numero de registros recuperados de las estaciones: 1066225
#    Numero de estaciones: 0
#    Numero de estaciones: 0
#    Numero de registros recuperados de las estaciones: 1121270
#    Numero de estaciones: 4
#    Numero de estaciones: 0
#    Numero de registros recuperados de las estaciones: 1078279
#    Numero de estaciones: 0
#    Numero de estaciones: 0
#    Numero de registros recuperados de las estaciones: 1115296
#    Numero de estaciones: 0
#    Numero de estaciones: 0
#    Numero de registros recuperados de las estaciones: 1255987
#    Numero de estaciones: 0
#    Numero de estaciones: 0
#    Numero de registros recuperados de las estaciones: 862699
#    Numero de estaciones: 0
#    Numero de estaciones: 0
#    Numero de registros recuperados de las estaciones: 1018893
#    Numero de estaciones: 0
#    Numero de estaciones: 0
#    Numero de registros recuperados de las estaciones: 1260996
#    Numero de estaciones: 0
#    Numero de estaciones: 0
#    Numero de registros recuperados de las estaciones: 1054728
#    Numero de estaciones: 0
#    Numero de estaciones: 0
#    Numero de registros recuperados de las estaciones: 1067262
#    Numero de estaciones: 0
#    Numero de estaciones: 0
#    Numero de registros recuperados de las estaciones: 118710
#    Numero de estaciones: 0
#    Numero de estaciones: 0
# Inicio continente: central_america a las 16:48:43
#    Numero estaciones en el año inicial: 94
#    Numero estaciones en el año final: 81
#    Numero estaciones comunes: 22
#    Numero de registros recuperados de las estaciones: 204283
#    Numero de estaciones: 1
#    Numero de estaciones: 1
# Inicio continente: south_america a las 16:55:56
#    Numero estaciones en el año inicial: 1648
#    Numero estaciones en el año final: 255
#    Numero estaciones comunes: 58
#    Numero de registros recuperados de las estaciones: 422556
#    Numero de estaciones: 0
#    Numero de estaciones: 0
# Inicio continente: antarctica a las 16:58:23
#    Numero estaciones en el año inicial: 8
#    Numero estaciones en el año final: 44
#    Numero estaciones comunes: 5
#    Numero de registros recuperados de las estaciones: 62883
#    Numero de estaciones: 0
#    Numero de estaciones: 0
