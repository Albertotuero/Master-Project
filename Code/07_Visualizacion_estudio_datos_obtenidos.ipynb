# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline 
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 7, 3

df = pd.read_csv("../datos/Resultados/Resultado_calentamiento_1900_2015.csv")

df = df[df.year >= 1900]
df = df[df.year <= 2015]

sub_df_europa = df[df.continent == "europa"]
sub_df_na = df[df.continent == "north_america"]
sub_df_oceania = df[df.continent == "oceania"]

# %% [markdown]
# ## Análisis Europa

# %%
plt.plot(sub_df_europa.year,sub_df_europa.tmax)
plt.grid(True)
plt.title('Europa - Mediana anual temperatura maxima')

# %%
sub_df_europa_1 = sub_df_europa[sub_df_europa.tmax >= 14]
sub_df_europa_1
# Out:
#      year  tmax  max_tmax  std_tmax  min_tmax  std_tmin  min_tmin  tmin  \
# 43   1943  14.4      37.4  8.612339      -9.2  6.447123     -16.6  4.50
# 49   1949  14.6      35.0  8.657274      -9.4  6.390982     -13.4  5.40
# 53   1953  14.0      32.5  8.819099      -9.3  6.715043     -19.1  5.00
# 59   1959  14.3      38.4  8.789053      -7.7  6.485564     -17.3  4.30
# 61   1961  14.1      34.0  8.264488     -12.0  6.630752     -19.5  5.70
# 99   1999  14.0      35.2  8.788379      -9.7  6.551269     -13.9  5.80
# 105  2005  14.1      34.9  9.104486     -10.8  7.068039     -18.8  5.25
# 106  2006  14.4      36.9  9.505643     -12.3  7.466190     -18.0  6.40
# 107  2007  14.2      37.2  8.041448      -8.9  5.937917     -13.5  5.50
# 109  2009  14.1      34.2  9.109021     -11.9  7.032134     -20.9  5.60
# 111  2011  14.8      34.3  8.409748      -7.3  6.411523     -13.5  5.70
# 114  2014  15.0      35.5  7.870264      -9.6  5.872741     -13.4  6.30
# ...

# %%
plt.plot(sub_df_europa.year,sub_df_europa.min_tmax)
plt.grid(True)
plt.title('Europa - Minima anual temperatura maxima')

# %%
sub_df_europa_1 = sub_df_europa[sub_df_europa.min_tmax >= -7]
sub_df_europa_1
# Out:
#      year   tmax  max_tmax  std_tmax  min_tmax  std_tmin  min_tmin  tmin  \
# 10   1910  12.00      32.0  7.798460      -5.9  6.073846     -13.0  4.15
# 13   1913  12.45      30.6  7.524116      -6.7  5.892776     -13.8  5.50
# 16   1916  12.50      29.5  7.410555      -6.1  5.656500      -9.3  4.60
# 51   1951  12.60      33.4  7.968126      -5.0  6.089640     -17.4  4.50
# 58   1958  11.70      32.2  8.535678      -6.8  6.874768     -15.3  4.30
# 74   1974  12.00      35.5  7.295141      -4.2  5.196026     -11.7  4.40
# 77   1977  13.20      31.9  7.705989      -6.9  5.915830     -15.3  4.90
# 89   1989  13.50      35.3  8.066550      -4.2  6.033563     -12.5  5.50
# 90   1990  13.80      34.1  7.741220      -6.0  5.689799     -11.8  5.70
# 115  2015  14.20      37.8  8.341670      -6.5  6.098343      -9.1  5.40
#
#      max_tmin continent     period
# 10       20.5    europa  1900-2015
# 13       18.5    europa  1900-2015
# 16       17.2    europa  1900-2015
# ...

# %%
plt.plot(sub_df_europa.year,sub_df_europa.max_tmax)
plt.grid(True)
plt.title('Europa - Maxima anual temperatura maxima')

# %%
sub_df_europa_1 = sub_df_europa[sub_df_europa.max_tmax >= 37]
sub_df_europa_1
# Out:
#      year   tmax  max_tmax   std_tmax  min_tmax  std_tmin  min_tmin  tmin  \
# 21   1921  13.90      37.3   8.835239      -8.0  6.684037     -17.6  4.90
# 32   1932  11.50      37.2   8.978446     -14.5  7.376444     -19.1  4.30
# 43   1943  14.40      37.4   8.612339      -9.2  6.447123     -16.6  4.50
# 47   1947  13.80      37.5  11.103163     -15.3  8.678827     -22.6  5.00
# 52   1952  11.75      37.3   9.113066      -7.6  6.722066     -16.6  3.90
# 57   1957  12.70      38.0   7.972963     -10.7  6.176429     -16.7  4.60
# 59   1959  14.30      38.4   8.789053      -7.7  6.485564     -17.3  4.30
# 92   1992  12.40      38.6   8.814213      -8.1  6.538473     -13.9  4.40
# 94   1994  13.00      37.5   8.526914      -8.4  6.502675     -14.3  5.65
# 98   1998  12.90      37.7   8.459186      -9.9  6.703902     -19.9  5.80
# 103  2003  13.70      37.5   9.813646     -11.0  7.666728     -16.1  4.80
# 107  2007  14.20      37.2   8.041448      -8.9  5.937917     -13.5  5.50
# ...

# %%
plt.plot(sub_df_europa.year,sub_df_europa.min_tmax)
plt.plot(sub_df_europa.year,sub_df_europa.max_tmax)
plt.grid(True)
plt.title('Europa - Maximo y Minimo anual temperatura maxima')

# %%
plt.plot(sub_df_europa.year,sub_df_europa.tmin)
plt.grid(True)
plt.title('Europa - Mediana anual temperatura minima')

# %%
sub_df_europa_1 = sub_df_europa[sub_df_europa.tmin >= 5.5]
sub_df_europa_1
# Out:
#      year   tmax  max_tmax  std_tmax  min_tmax  std_tmin  min_tmin  tmin  \
# 13   1913  12.45      30.6  7.524116      -6.7  5.892776     -13.8  5.50
# 61   1961  14.10      34.0  8.264488     -12.0  6.630752     -19.5  5.70
# 83   1983  13.00      36.5  9.121763     -10.6  7.270622     -14.8  5.60
# 89   1989  13.50      35.3  8.066550      -4.2  6.033563     -12.5  5.50
# 90   1990  13.80      34.1  7.741220      -6.0  5.689799     -11.8  5.70
# 94   1994  13.00      37.5  8.526914      -8.4  6.502675     -14.3  5.65
# 98   1998  12.90      37.7  8.459186      -9.9  6.703902     -19.9  5.80
# 99   1999  14.00      35.2  8.788379      -9.7  6.551269     -13.9  5.80
# 100  2000  13.80      36.6  8.081167     -11.5  5.966220     -14.5  6.40
# 101  2001  13.20      36.0  8.838592     -14.8  6.807963     -20.1  5.70
# 102  2002  12.90      34.2  8.441636      -8.7  6.642676     -23.5  5.50
# 106  2006  14.40      36.9  9.505643     -12.3  7.466190     -18.0  6.40
# ...

# %%
plt.plot(sub_df_europa.year,sub_df_europa.max_tmin)
plt.grid(True)
plt.title('Europa - Maxima anual temperatura minima')

# %%
sub_df_europa_1 = sub_df_europa[sub_df_europa.max_tmin >= 23]
sub_df_europa_1
# Out:
#     year  tmax  max_tmax  std_tmax  min_tmax  std_tmin  min_tmin  tmin  \
# 14  1914  11.7      31.7  8.233845     -12.4  6.485269     -14.9  5.20
# 57  1957  12.7      38.0  7.972963     -10.7  6.176429     -16.7  4.60
# 94  1994  13.0      37.5  8.526914      -8.4  6.502675     -14.3  5.65
#
#     max_tmin continent     period
# 14      23.0    europa  1900-2015
# 57      23.4    europa  1900-2015
# 94      24.4    europa  1900-2015

# %%
plt.plot(sub_df_europa.year,sub_df_europa.min_tmin)
plt.grid(True)
plt.title('Europa - Minima anual temperatura minima')

# %%
plt.plot(sub_df_europa.year,sub_df_europa.min_tmin)
plt.plot(sub_df_europa.year,sub_df_europa.max_tmin)
plt.grid(True)
plt.title('Europa - Maximo y Minimo anual temperatura minima')

# %% [markdown]
# ## Análisis Oceanía

# %%
plt.plot(sub_df_oceania.year,sub_df_oceania.tmax)
plt.grid(True)
plt.title('Oceania - Mediana anual temperatura maxima')

# %%
sub_df_oceania[sub_df_oceania["tmax"] > 22.5]
# Out:
#      year       tmax   max_tmax  std_tmax  min_tmax  std_tmin  min_tmin  \
# 130  1914  22.700000  41.200000  5.907960      9.00  4.900665 -0.300000
# 135  1919  22.600000  41.400000  5.634912      8.50  4.826463 -1.100000
# 152  1936  22.600000  40.900000  5.576191      9.70  4.793262  0.400000
# 156  1940  22.550000  43.800000  5.837113      9.90  4.933425 -0.500000
# 177  1961  22.600000  43.066667  5.545675     10.60  4.656691  0.800000
# 185  1969  22.558333  42.833333  5.829370      8.30  4.771420 -0.800000
# 188  1972  22.800000  40.800000  5.592716      8.60  4.853166 -0.050000
# 189  1973  22.783333  40.150000  5.766100      6.95  4.924078 -0.700000
# 191  1975  22.762500  42.075000  5.566578      6.75  4.645615  0.800000
# 192  1976  22.716667  41.000000  5.627732      8.55  4.906466 -0.700000
# 193  1977  22.970833  41.600000  6.104645      8.15  5.011516  0.850000
# 195  1979  22.812500  41.725000  5.933499     10.50  5.074321  0.350000
# ...

# %%
plt.plot(sub_df_oceania.year,sub_df_oceania.max_tmax)
plt.grid(True)
plt.title('Oceania - Maximo anual temperatura maxima')

# %%
sub_df_oceania_1 = sub_df_oceania[sub_df_oceania.max_tmax >= 44]
sub_df_oceania_1
# Out:
#      year   tmax  max_tmax  std_tmax  min_tmax  std_tmin  min_tmin       tmin  \
# 124  1908  22.20    44.200  6.259938      7.50  5.094798     -1.10  12.700000
# 149  1933  21.70    44.600  5.719269      9.10  4.888012      0.10  12.800000
# 155  1939  22.10    45.600  5.576319      9.50  4.868626     -1.10  12.700000
# 207  1991  23.05    45.075  5.893773      9.65  4.790550      1.60  12.775000
# 219  2003  23.00    44.350  5.683675     10.30  4.832247      0.95  12.925000
# 225  2009  23.35    46.600  5.844422     10.55  4.938860      2.05  12.958333
#
#      max_tmin continent     period
# 124     24.50   oceania  1900-2015
# 149     29.30   oceania  1900-2015
# 155     24.60   oceania  1900-2015
# 207     24.95   oceania  1900-2015
# 219     25.40   oceania  1900-2015
# 225     28.10   oceania  1900-2015

# %%
plt.plot(sub_df_oceania.year,sub_df_oceania.min_tmax)
plt.grid(True)
plt.title('Oceania - Minimo anual temperatura maxima')

# %%
sub_df_oceania_1 = sub_df_oceania[sub_df_oceania.min_tmax >= 9.5]
sub_df_oceania_1
# Out:
#      year       tmax   max_tmax  std_tmax  min_tmax  std_tmin  min_tmin  \
# 120  1904  21.700000  42.200000  5.955769     10.30  4.794063 -0.300000
# 128  1912  22.200000  41.400000  5.967226     10.10  4.740658 -0.700000
# 129  1913  21.700000  41.200000  5.939898     10.30  4.694128 -0.700000
# 131  1915  22.300000  41.800000  6.019693     10.20  4.573757  0.300000
# 132  1916  21.800000  40.100000  5.623671      9.70  4.680877 -1.100000
# 136  1920  21.900000  41.600000  5.726140      9.50  4.662728  1.100000
# 139  1923  22.300000  41.900000  5.854751     10.00  4.601681  1.200000
# 142  1926  22.300000  42.100000  5.889124      9.50  4.592325  0.000000
# 146  1930  22.000000  42.200000  5.459868     10.00  4.490734  1.000000
# 152  1936  22.600000  40.900000  5.576191      9.70  4.793262  0.400000
# 154  1938  22.400000  39.700000  5.562353     10.10  4.892579 -1.300000
# 155  1939  22.100000  45.600000  5.576319      9.50  4.868626 -1.100000
# ...

# %%
plt.plot(sub_df_oceania.year,sub_df_oceania.min_tmax)
plt.plot(sub_df_oceania.year,sub_df_oceania.max_tmax)
plt.grid(True)
plt.title('Oceania - Maximo y Minimo anual temperatura maxima')

# %%
plt.plot(sub_df_oceania.year,sub_df_oceania.tmin)
plt.grid(True)
plt.title('Oceania - Mediana anual temperatura minima')

# %%
sub_df_oceania_1 = sub_df_oceania[sub_df_oceania.tmin >= 13.25]
sub_df_oceania_1
# Out:
#      year       tmax  max_tmax  std_tmax  min_tmax  std_tmin  min_tmin  \
# 130  1914  22.700000    41.200  5.907960      9.00  4.900665     -0.30
# 137  1921  22.300000    42.400  5.531755      8.50  4.645820      0.50
# 146  1930  22.000000    42.200  5.459868     10.00  4.490734      1.00
# 204  1988  22.800000    40.825  5.713333     10.20  4.494864      2.45
# 229  2013  23.400000    42.600  5.513206      9.05  4.739348      1.15
# 230  2014  23.441667    43.900  5.485199     10.25  4.828686      0.70
#
#           tmin  max_tmin continent     period
# 130  13.300000     26.70   oceania  1900-2015
# 137  13.500000     26.20   oceania  1900-2015
# 146  13.250000     26.90   oceania  1900-2015
# 204  13.550000     23.80   oceania  1900-2015
# 229  13.687500     26.15   oceania  1900-2015
# 230  13.541667     28.35   oceania  1900-2015

# %%
plt.plot(sub_df_oceania.year,sub_df_oceania.max_tmin)
plt.grid(True)
plt.title('Oceania - Maximo anual temperatura minima')

# %%
sub_df_oceania_1 = sub_df_oceania[sub_df_oceania.max_tmin >= 28]
sub_df_oceania_1
# Out:
#      year       tmax  max_tmax  std_tmax  min_tmax  std_tmin  min_tmin  \
# 118  1902  22.300000    42.700  5.858351      8.70  4.796480     -1.30
# 149  1933  21.700000    44.600  5.719269      9.10  4.888012      0.10
# 150  1934  21.800000    43.400  5.556681      6.90  4.823449      0.10
# 156  1940  22.550000    43.800  5.837113      9.90  4.933425     -0.50
# 171  1955  21.950000    41.150  5.705064      9.70  5.107075      0.40
# 213  1997  22.987500    43.225  5.859166     10.15  5.091576     -0.45
# 225  2009  23.350000    46.600  5.844422     10.55  4.938860      2.05
# 230  2014  23.441667    43.900  5.485199     10.25  4.828686      0.70
#
#           tmin  max_tmin continent     period
# 118  12.400000     30.50   oceania  1900-2015
# 149  12.800000     29.30   oceania  1900-2015
# 150  12.800000     28.30   oceania  1900-2015
# 156  12.300000     28.00   oceania  1900-2015
# 171  12.500000     28.35   oceania  1900-2015
# 213  12.800000     28.05   oceania  1900-2015
# ...

# %%
plt.plot(sub_df_oceania.year,sub_df_oceania.min_tmin)
plt.grid(True)
plt.title('Oceania - Minimo anual temperatura minima')

# %%
sub_df_oceania_1 = sub_df_oceania[sub_df_oceania.min_tmin > 0.8]
print(len(sub_df_oceania_1))
sub_df_oceania_1
# Out:
# 32
#      year       tmax   max_tmax  std_tmax  min_tmax  std_tmin  min_tmin  \
# 116  1900  21.550000  41.600000  6.163487      7.70  4.798603  1.000000
# 136  1920  21.900000  41.600000  5.726140      9.50  4.662728  1.100000
# 139  1923  22.300000  41.900000  5.854751     10.00  4.601681  1.200000
# 146  1930  22.000000  42.200000  5.459868     10.00  4.490734  1.000000
# 167  1951  22.050000  40.550000  5.543607      7.70  4.714023  1.100000
# 169  1953  22.450000  42.500000  5.565504      9.00  4.715929  0.900000
# 180  1964  21.925000  40.900000  5.469431      9.45  4.664033  1.900000
# 183  1967  22.250000  41.000000  5.576520      9.10  4.636317  1.200000
# 184  1968  22.100000  43.700000  6.093143      8.80  5.077931  0.925000
# 193  1977  22.970833  41.600000  6.104645      8.15  5.011516  0.850000
# 194  1978  22.425000  41.075000  6.137129      9.10  5.054075  1.500000
# 196  1980  22.900000  41.950000  5.954168      9.45  4.795316  1.550000
# ...

# %%
plt.plot(sub_df_oceania.year,sub_df_oceania.min_tmin)
plt.plot(sub_df_oceania.year,sub_df_oceania.max_tmin)
plt.grid(True)
plt.title('Oceania - Maximo y Minimo anual temperatura minima')

# %% [markdown]
# ## Análisis Norte América

# %%
plt.plot(sub_df_na.year,sub_df_na.tmax)
plt.grid(True)
plt.title('Norte America - Mediana Anual temperatura maxima')

# %%
sub_df_na_1 = sub_df_na[sub_df_na.tmax > 19.3]
print(len(sub_df_na_1))
sub_df_na_1
# Out:
# 15
#      year       tmax   max_tmax   std_tmax   min_tmax   std_tmin   min_tmin  \
# 242  1910  19.600000  44.150000  11.837415 -26.100000  10.477132 -40.000000
# 253  1921  19.875000  41.675000  11.273242 -28.900000  10.063480 -38.300000
# 254  1922  19.400000  43.175000  11.961049 -27.800000  10.866988 -45.600000
# 263  1931  19.433333  43.460000  11.180050 -18.500000   9.735859 -32.200000
# 266  1934  20.000000  46.950000  12.175800 -28.900000  10.682459 -37.200000
# 270  1938  19.880000  43.300000  11.578211 -35.250000  10.339023 -45.800000
# 271  1939  19.680000  45.300000  11.655042 -31.950000  10.444519 -44.150000
# 278  1946  19.613393  44.700000  10.758813 -23.900000   9.914116 -40.733333
# 281  1949  19.700000  42.233333  11.706044 -29.200000  10.861325 -40.033333
# 285  1953  19.340000  43.683333  11.220385 -28.900000   9.710736 -37.200000
# 287  1955  19.616667  42.911111  12.526361 -24.450000  11.283700 -38.225000
# ...

# %%
plt.plot(sub_df_na.year,sub_df_na.max_tmax)
plt.grid(True)
plt.title('Norte America - Maxima anual temperatura maxima')

# %%
plt.plot(sub_df_na.year,sub_df_na.min_tmax)
plt.grid(True)
plt.title('Norte America - Minimo anual temperatura maxima')

# %%
plt.plot(sub_df_na.year,sub_df_na.min_tmax)
plt.plot(sub_df_na.year,sub_df_na.max_tmax)
plt.grid(True)
plt.title('Norte America - Maximo y Minimo anual temperatura maxima')

# %%
plt.plot(sub_df_na.year,sub_df_na.tmin)
plt.grid(True)
plt.title('Norte America - Mediana anual temperatura minima')

# %%
sub_df = sub_df_na[sub_df_na.tmin > 5.7]
sub_df
# Out:
#      year       tmax   max_tmax   std_tmax  min_tmax   std_tmin   min_tmin  \
# 232  1900  19.266667  44.450000  11.952931   -31.700  10.906118 -40.000000
# 253  1921  19.875000  41.675000  11.273242   -28.900  10.063480 -38.300000
# 254  1922  19.400000  43.175000  11.961049   -27.800  10.866988 -45.600000
# 263  1931  19.433333  43.460000  11.180050   -18.500   9.735859 -32.200000
# 266  1934  20.000000  46.950000  12.175800   -28.900  10.682459 -37.200000
# 270  1938  19.880000  43.300000  11.578211   -35.250  10.339023 -45.800000
# 273  1941  18.900000  42.233333  11.626905   -27.800  10.232086 -36.950000
# 278  1946  19.613393  44.700000  10.758813   -23.900   9.914116 -40.733333
# 309  1977  19.300000  41.660000  12.293104   -31.850  11.364772 -42.450000
# 318  1986  18.900000  42.766667  11.250051   -26.000  10.212489 -35.550000
# 330  1998  18.900000  42.800000  11.093187   -30.500   9.722587 -35.800000
# ...

# %%
plt.plot(sub_df_na.year,sub_df_na.max_tmin)
plt.grid(True)
plt.title('Norte America - Maximo anual temperatura minima')

# %%
sub_df_na.max_tmin = sub_df_na.max_tmin.map(lambda x : min(x,35))
plt.plot(sub_df_na.year,sub_df_na.max_tmin)
plt.grid(True)
plt.title('Norte America - Maximo anual temperatura minima')
# Out:
# C:\Users\Alberto\Anaconda2\lib\site-packages\pandas\core\generic.py:2698: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
plt.plot(sub_df_na.year,sub_df_na.min_tmin)
plt.grid(True)
plt.title('Norte America - Minimo anual temperatura minima')

# %%
sub_df = sub_df_na[sub_df_na.min_tmin > -34.8]
print(len(sub_df))
sub_df
# Out:
# 13
#      year       tmax   max_tmax   std_tmax   min_tmax   std_tmin   min_tmin  \
# 263  1931  19.433333  43.460000  11.180050 -18.500000   9.735859 -32.200000
# 290  1958  18.780000  42.833333  11.750882 -24.450000  10.547074 -34.780000
# 292  1960  18.750000  42.400000  12.157757 -22.200000  10.879182 -34.271429
# 319  1987  19.100000  40.300000  10.984348 -20.283333   9.697828 -33.700000
# 327  1995  18.000000  42.600000  11.777115 -24.633333  10.540802 -32.850000
# 331  1999  19.150000  42.600000  10.833628 -22.400000   9.849079 -33.700000
# 332  2000  18.994118  42.033333  11.703954 -23.600000  10.587491 -33.900000
# 333  2001  18.900000  41.500000  11.216501 -20.200000  10.092848 -31.866667
# 334  2002  17.766667  43.300000  11.344117 -22.450000  10.293887 -32.850000
# 338  2006  18.500000  45.000000  10.707344 -23.600000   9.585532 -32.766667
# 339  2007  19.700000  42.600000  12.150254 -24.100000  10.802936 -34.633333
# ...

# %%
plt.plot(sub_df_na.year,sub_df_na.min_tmin)
plt.plot(sub_df_na.year,sub_df_na.max_tmin)
plt.grid(True)
plt.title('Norte America - Maximo y Minimo anual temperatura minima')

# %% [markdown]
# ## Consolidación de las ejecuciones para Tableau

# %%
# Unificación de resultados
df_total = pd.read_csv("../datos/Resultados/Resultado_calentamiento_1900_2015.csv")
df = pd.read_csv("../datos/Resultados/Resultado_calentamiento_1950_2015.csv")
df_total = df_total.append(df)
df = pd.read_csv("../datos/Resultados/Resultado_calentamiento_1970_2015.csv")
df_total = df_total.append(df)

# %%
df_total.loc[df_total['continent'] == "europa", 'continent'] = "Europa"
df_total.loc[df_total['continent'] == "north_america", 'continent'] = "Norte América"
df_total.loc[df_total['continent'] == "oceania", 'continent'] = "Oceanía"
df_total.loc[df_total['continent'] == "africa", 'continent'] = "Africa"
df_total.loc[df_total['continent'] == "asia", 'continent'] = "Asia"
df_total.loc[df_total['continent'] == "central_america", 'continent'] = "América Central"
df_total.loc[df_total['continent'] == "south_america", 'continent'] = "América del Sur"
df_total.loc[df_total['continent'] == "antarctica", 'continent'] = "Antártida"

# %%
df_total.head()
# Out:
#    year   tmax  max_tmax  std_tmax  min_tmax  std_tmin  min_tmin  tmin  \
# 0  1900  11.55      34.2  8.617652     -10.4  6.583136     -14.5  4.20
# 1  1901  11.90      33.1  9.452090     -13.5  7.903590     -23.8  4.30
# 2  1902  10.55      33.7  8.119004     -10.6  6.743543     -17.1  3.10
# 3  1903  12.20      32.4  8.173451     -11.0  6.421219     -17.6  4.45
# 4  1904  12.00      35.9  8.692687      -7.2  6.287935     -14.0  4.10
#
#    max_tmin continent     period
# 0      21.0    Europa  1900-2015
# 1      20.2    Europa  1900-2015
# 2      18.5    Europa  1900-2015
# 3      18.2    Europa  1900-2015
# 4      19.4    Europa  1900-2015

# %%
df_total.to_csv("../datos/Resultados/Resultado_calentamiento_total.csv")

# %%
cat = pd.read_csv('../datos/ghcnd-stations-cluster.csv',sep=";",decimal=",")

# %%
cat.head()
# Out:
#    Unnamed: 0 COUNTRY         ID  LATITUDE  LONGITUDE STATE  \
# 0           1      AC  W00011604   17.1167   -61.7833   NaN
# 1           2      AC  W00011647   17.1333   -61.7833   NaN
# 2           3      AE  000041196   25.3330    55.5170   NaN
# 3           4      AE  M00041194   25.2550    55.3640   NaN
# 4           5      AE  M00041217   24.4330    54.6510   NaN
#
#                     NAME    ORIG_ID              ORIG_NAME  ORIG_LAT  \
# 0  ST JOHNS COOLIDGE FLD  W00011604  ST JOHNS COOLIDGE FLD   17.1167
# 1               ST JOHNS  W00011647               ST JOHNS   17.1333
# 2    SHARJAH INTER. AIRP  000041196    SHARJAH INTER. AIRP   25.3330
# 3             DUBAI INTL  M00041194             DUBAI INTL   25.2550
# 4         ABU DHABI INTL  M00041217         ABU DHABI INTL   24.4330
#
#    ORIG_LNG  cluster
# 0  -61.7833        0
# 1  -61.7833        0
# 2   55.5170        0
# 3   55.3640        0
# 4   54.6510        0

# %%
# Lectura del catálogo de estaciones
cat = pd.read_csv('../datos/ghcnd-stations-cluster.csv',sep=";",decimal=",")
cat = cat[["COUNTRY","ID","ORIG_NAME","LATITUDE","LONGITUDE"]]
cat.columns = ["country","id","name","lat","lng"]
cat["station"] = cat.country + cat.id
cat = cat.drop_duplicates("station")
cat.head()
# Out:
#   country         id                   name      lat      lng      station
# 0      AC  W00011604  ST JOHNS COOLIDGE FLD  17.1167 -61.7833  ACW00011604
# 1      AC  W00011647               ST JOHNS  17.1333 -61.7833  ACW00011647
# 2      AE  000041196    SHARJAH INTER. AIRP  25.3330  55.5170  AE000041196
# 3      AE  M00041194             DUBAI INTL  25.2550  55.3640  AEM00041194
# 4      AE  M00041217         ABU DHABI INTL  24.4330  54.6510  AEM00041217

# %%
from pandas import DataFrame

df_selected_stations=DataFrame()
df = pd.read_csv("../datos/Resultados/Resultado_calentamiento_1900_2015_estaciones.csv")
df = df[["station","continent","period"]]
df = df.merge(cat,on="station")
df_selected_stations = df_selected_stations.append(df)

df = pd.read_csv("../datos/Resultados/Resultado_calentamiento_1950_2015_estaciones.csv")
df = df[["station","continent","period"]]
df = df.merge(cat,on="station")
df_selected_stations = df_selected_stations.append(df)

df = pd.read_csv("../datos/Resultados/Resultado_calentamiento_1970_2015_estaciones.csv")
df = df[["station","continent","period"]]
df = df.merge(cat,on="station")
df_selected_stations = df_selected_stations.append(df)

# %%
df_selected_stations.loc[df_selected_stations['continent'] == "europa", 'continent'] = "Europa"
df_selected_stations.loc[df_selected_stations['continent'] == "north_america", 'continent'] = "Norte América"
df_selected_stations.loc[df_selected_stations['continent'] == "oceania", 'continent'] = "Oceanía"
df_selected_stations.loc[df_selected_stations['continent'] == "africa", 'continent'] = "Africa"
df_selected_stations.loc[df_selected_stations['continent'] == "asia", 'continent'] = "Asia"
df_selected_stations.loc[df_selected_stations['continent'] == "central_america", 'continent'] = "América Central"
df_selected_stations.loc[df_selected_stations['continent'] == "south_america", 'continent'] = "América del Sur"
df_selected_stations.loc[df_selected_stations['continent'] == "antarctica", 'continent'] = "Antártida"

df_selected_stations
# Out:
#            station        continent     period country         id  \
# 0      GM000003342           Europa  1900-2015      GM  000003342
# 1      GM000004063           Europa  1900-2015      GM  000004063
# 2      GM000010147           Europa  1900-2015      GM  000010147
# 3      GM000010962           Europa  1900-2015      GM  000010962
# 4      ASN00009917          Oceanía  1900-2015      AS  N00009917
# 5      ASN00040978          Oceanía  1900-2015      AS  N00040978
# 6      ASN00066195          Oceanía  1900-2015      AS  N00066195
# 7      ASN00086232          Oceanía  1900-2015      AS  N00086232
# 8      CA001018629    Norte América  1900-2015      CA  001018629
# 9      CA001163842    Norte América  1900-2015      CA  001163842
# 10     CA003012216    Norte América  1900-2015      CA  003012216
# 11     CA003031092    Norte América  1900-2015      CA  003031092
# 12     CA004028040    Norte América  1900-2015      CA  004028040
# ...

# %%
df_selected_stations.to_csv("../datos/Resultados/Resultado_calentamiento_estaciones.csv")
